# %%
import json

with open("aquinas_new.json", "r") as handle:
    data = json.load(handle)
data[0]
# Out:
# {'volume': 'Volume 1',
#  'volumeKey': 'v1',
#  'questionTitle': 'Question 1. The nature and extent of sacred doctrine',
#  'question': 'Question 1.',
#  'questionKey': 'q1',
#  'articleTitle': 'Article 1. Whether, besides philosophy, any further doctrine is required?',
#  'article': 'Article 1.',
#  'articleKey': 'a1',
#  'articleObjections': ['Objection 1. It seems that, besides philosophical science, we have no need of any further knowledge. For man should not seek to know what is above reason: "Seek not the things that are too high for thee" (Sirach 3:22). But whatever is not above reason is fully treated of in philosophical science. Therefore any other knowledge besides philosophical science is superfluous.',
#   'Objection 2. Further, knowledge can be concerned only with being, for nothing can be known, save what is true; and all that is, is true. But everything that is, is treated of in philosophical science—even God Himself; so that there is a part of philosophy called theology, or the divine science, as Aristotle has proved (Metaph. vi). Therefore, besides philosophical science, there is no need of any further knowledge.'],
#  'articleBody': ['On the contrary, It is written (2 Timothy 3:16): "All Scripture, inspired of God is profitable to teach, to reprove, to correct, to instruct in justice." Now Scripture, inspired of God, is no part of philosophical science, which has been built up by human reason. Therefore it is useful that besides philosophical science, there should be other knowledge, i.e. inspired of God.',
#   'I answer that, It was necessary for man\'s salvation that there should be a knowledge revealed by God besides philosophical science built up by human reason. Firstly, indeed, because man is directed to God, as to an end that surpasses the grasp of his reason: "The eye hath not seen, O God, besides Thee, what things Thou hast prepared for them that wait for Thee" (Isaiah 64:4). But the end must first be known by men who are to direct their thoughts and actions to the end. Hence it was necessary for the salvation of man that certain truths which exceed human reason should be made known to him by divine revelation. Even as regards those truths about God which human reason could have discovered, it was necessary that man should be taught by a divine revelation; because the truth about God such as reason could discover, would only be known by a few, and that after a long time, and with the admixture of many errors. Whereas man\'s whole salvation, which is in God, depends upon the knowledge of this truth. Therefore, in order that the salvation of men might be brought about more fitly and more surely, it was necessary that they should be taught divine truths by divine revelation. It was therefore necessary that besides philosophical science built up by reason, there should be a sacred science learned through revelation.'],
#  'articleReplyToObjections': ['Reply to Objection 1. Although those things which are beyond man\'s knowledge may not be sought for by man through his reason, nevertheless, once they are revealed by God, they must be accepted by faith. Hence the sacred text continues, "For many things are shown to thee above the understanding of man" (Sirach 3:25). And in this, the sacred science consists.',
#   'Reply to Objection 2. Sciences are differentiated according to the various means through which knowledge is obtained. For the astronomer and the physicist both may prove the same conclusion: that the earth, for instance, is round: the astronomer by means of mathematics (i.e. abstracting from matter), but the physicist by means of matter itself. Hence there is no reason why those things which may be learned from philosophical science, so far as they can be known by natural reason, may not also be taught us by another science so far as they fall within revelation. Hence theology included in sacred doctrine differs in kind from that theology which is part of philosophy.']}

# %%
import nltk
#nltk.download('wordnet')

lemma = nltk.wordnet.WordNetLemmatizer()


from collections import defaultdict, Counter
import spacy
nlp = spacy.load('en')
import tqdm

kill = set(['it', 'i', 'it', 'that', 'hath', 'thou', 'hast', 'that', 'who', 'it', 'which',
        'reason', 'it','we', 'which', 'which', 'it', 'which', 'this', 'others',
       'things', 'things', 'things', 'they', 'what', 'he', 'most', 'words', 'word', 'something', 'them', 'thing',
            'inasmuch', 'some', 'these', 'whence', 'whatever', '1', 'whoever', 'reply', 'both'
       ])

article_topics = {}
n = len(data)
for i, article in enumerate(data):
    if i % n == 25:
        print("%{} complete".format((i/n)*100))
    subjects = []
    for j, sentence in enumerate(nltk.sent_tokenize("\n".join([k for k in article["articleBody"]]))):
        doc = nlp(sentence)
        for word in doc:
            if word.dep_ == "nsubj":
                if not word.text.lower() in kill:
                    lemmatized_word = lemma.lemmatize(word.text.lower())

                    subjects.append(lemmatized_word)
    
    #dict(Counter(subjects).most_common())
    article_topics[i] = dict(Counter(subjects).most_common())
    #print("article{}".format(i), subjects)
# Out:
# %0.7941550190597205 complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-045637990206> in <module>
#      23     subjects = []
#      24     for j, sentence in enumerate(nltk.sent_tokenize("\n".join([k for k in article["articleBody"]]))):
# ---> 25         doc = nlp(sentence)
#      26         for word in doc:
#      27             if word.dep_ == "nsubj":
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     447             if not hasattr(proc, "__call__"):
#     448                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 449             doc = proc(doc, **component_cfg.get(name, {}))
#     450             if doc is None:
#     451                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# _parser_model.pyx in spacy.syntax._parser_model.precompute_hiddens.__init__()
#
# ~\Anaconda3\lib\site-packages\spacy\_ml.py in begin_update(self, X, drop)
#     178     def begin_update(self, X, drop=0.0):
#     179         Yf = self.ops.gemm(
# --> 180             X, self.W.reshape((self.nF * self.nO * self.nP, self.nI)), trans2=True
#     181         )
#     182         Yf = Yf.reshape((Yf.shape[0], self.nF, self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
data[0]
# Out:
# {'volume': 'Volume 1',
#  'volumeKey': 'v1',
#  'questionTitle': 'Question 1. The nature and extent of sacred doctrine',
#  'question': 'Question 1.',
#  'questionKey': 'q1',
#  'articleTitle': 'Article 1. Whether, besides philosophy, any further doctrine is required?',
#  'article': 'Article 1.',
#  'articleKey': 'a1',
#  'articleObjections': ['Objection 1. It seems that, besides philosophical science, we have no need of any further knowledge. For man should not seek to know what is above reason: "Seek not the things that are too high for thee" (Sirach 3:22). But whatever is not above reason is fully treated of in philosophical science. Therefore any other knowledge besides philosophical science is superfluous.',
#   'Objection 2. Further, knowledge can be concerned only with being, for nothing can be known, save what is true; and all that is, is true. But everything that is, is treated of in philosophical science—even God Himself; so that there is a part of philosophy called theology, or the divine science, as Aristotle has proved (Metaph. vi). Therefore, besides philosophical science, there is no need of any further knowledge.'],
#  'articleBody': ['On the contrary, It is written (2 Timothy 3:16): "All Scripture, inspired of God is profitable to teach, to reprove, to correct, to instruct in justice." Now Scripture, inspired of God, is no part of philosophical science, which has been built up by human reason. Therefore it is useful that besides philosophical science, there should be other knowledge, i.e. inspired of God.',
#   'I answer that, It was necessary for man\'s salvation that there should be a knowledge revealed by God besides philosophical science built up by human reason. Firstly, indeed, because man is directed to God, as to an end that surpasses the grasp of his reason: "The eye hath not seen, O God, besides Thee, what things Thou hast prepared for them that wait for Thee" (Isaiah 64:4). But the end must first be known by men who are to direct their thoughts and actions to the end. Hence it was necessary for the salvation of man that certain truths which exceed human reason should be made known to him by divine revelation. Even as regards those truths about God which human reason could have discovered, it was necessary that man should be taught by a divine revelation; because the truth about God such as reason could discover, would only be known by a few, and that after a long time, and with the admixture of many errors. Whereas man\'s whole salvation, which is in God, depends upon the knowledge of this truth. Therefore, in order that the salvation of men might be brought about more fitly and more surely, it was necessary that they should be taught divine truths by divine revelation. It was therefore necessary that besides philosophical science built up by reason, there should be a sacred science learned through revelation.'],
#  'articleReplyToObjections': ['Reply to Objection 1. Although those things which are beyond man\'s knowledge may not be sought for by man through his reason, nevertheless, once they are revealed by God, they must be accepted by faith. Hence the sacred text continues, "For many things are shown to thee above the understanding of man" (Sirach 3:25). And in this, the sacred science consists.',
#   'Reply to Objection 2. Sciences are differentiated according to the various means through which knowledge is obtained. For the astronomer and the physicist both may prove the same conclusion: that the earth, for instance, is round: the astronomer by means of mathematics (i.e. abstracting from matter), but the physicist by means of matter itself. Hence there is no reason why those things which may be learned from philosophical science, so far as they can be known by natural reason, may not also be taught us by another science so far as they fall within revelation. Hence theology included in sacred doctrine differs in kind from that theology which is part of philosophy.']}

# %%
dat["volumeKey"], dat["questionKey"], dat["articleKey"]
# Out:
# ('v1', 'q10', 'a6')

# %% [markdown]
# # What did we learn?

# %%
for i, dat in enumerate(data[:50]):
    print(i, dat["volume"], "\n", dat["questionTitle"], "\n", dat["articleTitle"], "\n", article_topics[i])
    print()
# Out:
# 0 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 1. Whether, besides philosophy, any further doctrine is required?
#  {'Scripture': 2, 'truth': 1, 'salvation': 1}
#
# 1 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 2. Whether sacred doctrine is a science?
#  {'doctrine': 3, 'Augustine': 1, 'Trin': 1, 'xiv': 1, 'musician': 1, 'principle': 1}
#
# 2 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 3. Whether sacred doctrine is one science?
#  {'Scripture': 2, 'Wisdom': 1, 'doctrine': 1, 'unity': 1, 'man': 1, 'stone': 1, 'color': 1}
#
# 3 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 4. Whether sacred doctrine is a practical science?
#  {'doctrine': 3, 'handiwork': 1, 'one': 1, 'God': 1}
#
# 4 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 5. Whether sacred doctrine is nobler than other sciences?
#  {'science': 6, 'Wisdom': 1, 'one': 1, 'purpose': 1}
#
# 5 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 6. Whether this doctrine is the same as wisdom?
#  {'doctrine': 1, 'stone': 1, 'Wisdom': 1, 'Augustine': 1, 'philosopher': 1}
#
# 6 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 7. Whether God is the object of this science?
#  {'object': 3, 'God': 3, 'treatment': 1, 'relation': 1, 'article': 1}
#
# 7 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 8. Whether sacred doctrine is a matter of argument?
#  {'opponent': 3, 'Scripture': 2, 'science': 2, 'bishop': 1, 'doctrine': 1, 'Apostle': 1, 'highest': 1, 'metaphysics': 1, 'faith': 1, 'argument': 1, 'difficulty': 1}
#
# 8 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 9. Whether Holy Scripture should use metaphors?
#  {'science': 1, 'God': 1, 'Dionysius': 1, 'simple': 1}
#
# 9 Volume 1
#  Question 1. The nature and extent of sacred doctrine
#  Article 10. Whether in Holy Scripture a word may have several senses?
#  {'author': 2, 'sense': 2, 'Law': 2, 'Gregory': 1, 'xx': 1, 'man': 1, 'science': 1, 'signification': 1, 'Apostle': 1, 'Dionysius': 1, 'Head': 1, 'Augustine': 1}
#
# 10 Volume 1
#  Question 2. The existence of God
#  Article 1. Whether the existence of God is self-evident?
#  {'proposition': 5, 'God': 4, 'one': 2, 'fool': 1, 'Man': 1, 'term': 1, 'essence': 1, 'Boethius': 1, 'title': 1, 'all': 1, 'substance': 1}
#
# 11 Volume 1
#  Question 2. The existence of God
#  Article 2. Whether it can be demonstrated that God exists?
#  {'effect': 2, 'Apostle': 1, 'One': 1, 'other': 1, 'cause': 1}
#
# 12 Volume 1
#  Question 2. The existence of God
#  Article 3. Whether God exists?
#  {'nothing': 3, 'way': 2, 'everyone': 2, 'cause': 2, 'being': 2, 'itself': 1, 'mover': 1, 'staff': 1, 'first': 1, 'intermediate': 1, 'all': 1, 'everything': 1, 'existence': 1, 'men': 1, 'maximum': 1}
#
# 13 Volume 1
#  Question 3. The simplicity of God
#  Article 1. Whether God is a body?
#  {'God': 8, 'body': 7, 'being': 1, 'potentiality': 1, 'actuality': 1, 'continuous': 1, 'animation': 1}
#
# 14 Volume 1
#  Question 3. The simplicity of God
#  Article 2. Whether God is composed of matter and form?
#  {'God': 4, 'matter': 2, 'everything': 1, 'good': 1, 'agent': 1, 'manner': 1}
#
# 15 Volume 1
#  Question 3. The simplicity of God
#  Article 3. Whether God is the same as His essence or nature?
#  {'humanity': 3, 'God': 2, 'man': 2, 'relation': 1, 'nature': 1, 'essence': 1, 'individualization': 1, 'form': 1}
#
# 16 Volume 1
#  Question 3. The simplicity of God
#  Article 4. Whether essence and existence are the same in God?
#  {'existence': 5, 'God': 3, 'Hilary': 1, 'faculty': 1, 'latter': 1, 'essence': 1, 'itself': 1}
#
# 17 Volume 1
#  Question 3. The simplicity of God
#  Article 5. Whether God is contained in a genus?
#  {'God': 7, 'being': 2, 'genus': 1, 'nothing': 1, 'actuality': 1, 'argument': 1, 'existence': 1, 'Philosopher': 1, 'difference': 1, 'all': 1, 'essence': 1, 'mean': 1, 'principle': 1, 'point': 1}
#
# 18 Volume 1
#  Question 3. The simplicity of God
#  Article 6. Whether in God there are any accidents?
#  {'God': 3, 'Boethius': 2, 'accident': 1, 'form': 1, 'essence': 1, 'substance': 1, 'heat': 1, 'capability': 1}
#
# 19 Volume 1
#  Question 3. The simplicity of God
#  Article 7. Whether God is altogether simple?
#  {'God': 5, 'composite': 2, 'part': 2, 'Augustine': 1, 'Trin': 1, 'nature': 1, 'volume': 1, 'Hilary': 1}
#
# 20 Volume 1
#  Question 3. The simplicity of God
#  Article 8. Whether God enters into the composition of other things?
#  {'God': 9, 'cause': 2, 'form': 2, 'Dionysius': 1, 'Philosopher': 1, 'error': 1, 'matter': 1, 'former': 1, 'latter': 1, 'composite': 1, 'hand': 1, 'part': 1, 'potentiality': 1, 'participates': 1, 'fire': 1}
#
# 21 Volume 1
#  Question 6. The goodness of God
#  Article 1. Whether God is good?
#  {'agent': 2, 'Lord': 1, 'everything': 1, 'perfection': 1, 'God': 1, 'aspect': 1, 'iv': 1}
#
# 22 Volume 1
#  Question 6. The goodness of God
#  Article 2. Whether God is the supreme good?
#  {'Augustine': 1, 'Trin': 1, 'Trinity': 1, 'God': 1, 'perfection': 1, 'heat': 1}
#
# 23 Volume 1
#  Question 6. The goodness of God
#  Article 3. Whether to be essentially good belongs to God alone?
#  {'perfection': 6, 'God': 2, 'Boethius': 1, 'essence': 1, 'Himself': 1}
#
# 24 Volume 1
#  Question 6. The goodness of God
#  Article 4. Whether all things are good by the divine goodness?
#  {'opinion': 2, 'Aristotle': 2, 'Plato': 1, 'good': 1, 'one': 1}
#
# 25 Volume 1
#  Question 5. Goodness in general
#  Article 1. Whether goodness differs really from being?
#  {'Goodness': 2, 'goodness': 2, 'Augustine': 1, 'Doctr': 1, 'essence': 1, 'Philosopher': 1, 'all': 1, 'everything': 1}
#
# 26 Volume 1
#  Question 5. Goodness in general
#  Article 2. Whether goodness is prior in idea to being?
#  {'first': 1, 'being': 1, 'mind': 1, 'everything': 1, 'sound': 1}
#
# 27 Volume 1
#  Question 5. Goodness in general
#  Article 3. Whether every being is good?
#  {'being': 4, 'creature': 1, 'God': 1, 'act': 1, 'perfection': 1}
#
# 28 Volume 1
#  Question 5. Goodness in general
#  Article 4. Whether goodness has the aspect of a final cause?
#  {'goodness': 4, 'Philosopher': 2, 'idea': 1, 'heat': 1, 'action': 1, 'form': 1, 'converse': 1, 'power': 1, 'iv': 1}
#
# 29 Volume 1
#  Question 5. Goodness in general
#  Article 5. Whether the essence of goodness consists in mode, species and order?
#  {'essence': 3, 'form': 3, 'Augustine': 1, 'Nat': 1, 'mode': 1, 'God': 1, 'three': 1, 'everything': 1, 'measure': 1, 'specie': 1, 'unit': 1, 'difference': 1}
#
# 30 Volume 1
#  Question 5. Goodness in general
#  Article 6. Whether goodness is rightly divided into the virtuous, the useful and the pleasant?
#  {'division': 2, 'honestum': 1, 'Ambrose': 1, 'everything': 1, 'movement': 1, 'appetite': 1, 'terminates': 1}
#
# 31 Volume 1
#  Question 4. The perfection of God
#  Article 1. Whether God is perfect?
#  {'principle': 3, 'philosopher': 2, 'you': 1, 'Father': 1, 'Philosopher': 1, 'God': 1}
#
# 32 Volume 1
#  Question 4. The perfection of God
#  Article 2. Whether the perfections of all things are in God?
#  {'God': 5, 'perfection': 4, 'Dionysius': 2, 'nothing': 2, 'Commentator': 1, 'man': 1, 'reproduces': 1, 'effect': 1, 'matter': 1, 'agent': 1, 'heat': 1}
#
# 33 Volume 1
#  Question 4. The perfection of God
#  Article 3. Whether any creature can be like God?
#  {'effect': 2, 'u': 1, 'agent': 1, 'everything': 1, 'man': 1, 'existence': 1, 'all': 1}
#
# 34 Volume 1
#  Question 7. The infinity of God
#  Article 1. Whether God is infinite?
#  {'God': 2, 'matter': 2, 'infinite': 2, 'Damascene': 1, 'philosopher': 1, 'body': 1, 'being': 1}
#
# 35 Volume 1
#  Question 7. The infinity of God
#  Article 2. Whether anything but God can be essentially infinite?
#  {'everything': 2, 'form': 2, 'infinite': 1, 'nothing': 1, 'matter': 1, 'wood': 1, 'case': 1}
#
# 36 Volume 1
#  Question 7. The infinity of God
#  Article 3. Whether an actually infinite magnitude can exist?
#  {'body': 13, 'same': 3, 'nothing': 3, 'creature': 2, 'accident': 2, 'surface': 1, 'another': 1, 'quantity': 1, 'place': 1, 'forasmuch': 1, 'line': 1, 'one': 1, 'form': 1}
#
# 37 Volume 1
#  Question 7. The infinity of God
#  Article 4. Whether an infinite multitude can exist?
#  {'multitude': 5, 'specie': 2, 'opinion': 1, 'generation': 1, 'existence': 1, 'another': 1, 'kind': 1, 'agent': 1, 'increase': 1, 'number': 1, 'infinite': 1}
#
# 38 Volume 1
#  Question 8. The existence of God in things
#  Article 1. Whether God is in all things?
#  {'God': 7, 'agent': 1, 'air': 1}
#
# 39 Volume 1
#  Question 8. The existence of God in things
#  Article 2. Whether God is everywhere?
#  {'God': 3, 'place': 1, 'accident': 1}
#
# 40 Volume 1
#  Question 8. The existence of God in things
#  Article 3. Whether God is everywhere by essence, presence and power?
#  {'God': 5, 'gloss': 1, 'quotation': 1, 'object': 1, 'creature': 1, 'substance': 1}
#
# 41 Volume 1
#  Question 8. The existence of God in things
#  Article 4. Whether to be everywhere belongs to God alone?
#  {'God': 2, 'Ambrose': 1, 'Spir': 1, 'forasmuch': 1, 'man': 1, 'whiteness': 1, 'grain': 1, 'body': 1, 'nothing': 1}
#
# 42 Volume 1
#  Question 9. The immutability of God
#  Article 1. Whether God is altogether immutable?
#  {'God': 3, 'everything': 3, 'being': 1, 'potentiality': 1, 'all': 1, 'movement': 1, 'principle': 1}
#
# 43 Volume 1
#  Question 9. The immutability of God
#  Article 2. Whether to be immutable belongs to God alone?
#  {'creature': 5, 'God': 4, 'matter': 2, 'Augustine': 1, 'Nat': 1, 'production': 1, 'those': 1, 'man': 1, 'privation': 1, 'form': 1, 'body': 1, 'subject': 1, 'forasmuch': 1, 'nothing': 1, 'kind': 1, 'Dionysius': 1, 'substance': 1, 'one': 1, 'Damascene': 1, 'other': 1, 'power': 1}
#
# 44 Volume 1
#  Question 10. The eternity of God
#  Article 1. Whether this is a good definition of eternity, "The simultaneously-whole and perfect possession of interminable life"?
#  {'idea': 2, 'succession': 1, 'part': 1, 'fact': 1, 'u': 1, 'eternity': 1}
#
# 45 Volume 1
#  Question 10. The eternity of God
#  Article 2. Whether God is eternal?
#  {'idea': 2, 'God': 2, 'Athanasius': 1, 'Father': 1, 'Son': 1, 'Ghost': 1, 'being': 1, 'other': 1}
#
# 46 Volume 1
#  Question 10. The eternity of God
#  Article 3. Whether to be eternal belongs to God alone?
#  {'God': 3, 'Jerome': 1, 'Eternity': 1, 'eternity': 1, 'thought': 1, 'Augustine': 1}
#
# 47 Volume 1
#  Question 10. The eternity of God
#  Article 4. Whether eternity differs from time?
#  {'time': 8, 'eternity': 3, 'movement': 2, 'Eternity': 1, 'Boethius': 1, 'infinite': 1, 'difference': 1}
#
# 48 Volume 1
#  Question 10. The eternity of God
#  Article 5. The difference of aeviternity and time
#  {'eternity': 4, 'being': 4, 'aeviternity': 3, 'time': 2, 'Boethius': 1, 'Aeviternity': 1, 'difference': 1, 'theory': 1, 'innovation': 1, 'incongruity': 1, 'fact': 1, 'measure': 1, 'anything': 1, 'movement': 1, 'their': 1, 'same': 1}
#
# 49 Volume 1
#  Question 10. The eternity of God
#  Article 6. Whether there is only one aeviternity?
#  {'time': 6, 'opinion': 3, 'measure': 3, 'number': 2, 'Aeviternity': 1, 'more': 1, 'unity': 1, 'duration': 1, 'Neither': 1, 'forasmuch': 1, 'all': 1, 'Origen': 1, 'substance': 1}

# %%
for i, article in enumerate(tqdm.tqdm(data[:50])):
    subjects = []
    for j, sentence in enumerate(nltk.sent_tokenize("\n".join([k for k in article["articleBody"]]))):
        doc = nlp(sentence)
        for word in doc:
            print(word.text, word.pos_)
    break
# Out:
#   0%|                                                                                           | 0/50 [00:00<?, ?it/s]
# On ADP
# the DET
# contrary NOUN
# , PUNCT
# It PRON
# is AUX
# written VERB
# ( PUNCT
# 2 NUM
# Timothy PROPN
# 3:16 NUM
# ) PUNCT
# : PUNCT
# " PUNCT
# All DET
# Scripture PROPN
# , PUNCT
# inspired VERB
# of ADP
# God PROPN
# is AUX
# profitable ADJ
# to PART
# teach VERB
# , PUNCT
# to PART
# reprove VERB
# , PUNCT
# to PART
# correct VERB
# , PUNCT
# to PART
# instruct VERB
# in ADP
# justice NOUN
# . PUNCT
# " PUNCT
# Now ADV
# Scripture NOUN
# , PUNCT
# inspired VERB
# of ADP
# God PROPN
# , PUNCT
# is AUX
# no DET
# part NOUN
# of ADP
# philosophical ADJ
# science NOUN
# , PUNCT
# which DET
# has AUX
# been AUX
# built VERB
# up ADP
# by ADP
# human ADJ
# reason NOUN
# . PUNCT
# Therefore ADV
# it PRON
# is AUX
# useful ADJ
# that SCONJ
# besides SCONJ
# philosophical ADJ
# science NOUN
# , PUNCT
# there PRON
# should VERB
# be AUX
# other ADJ
# knowledge NOUN
# , PUNCT
# i.e. X
# inspired VERB
# of ADP
# God PROPN
# . PUNCT
# I PRON
# answer VERB
# that DET
# , PUNCT
# It PRON
# was AUX
# necessary ADJ
# for ADP
# man NOUN
# 's PART
# salvation NOUN
# that SCONJ
# there PRON
# should VERB
# be AUX
# a DET
# knowledge NOUN
# revealed VERB
# by ADP
# God PROPN
# besides SCONJ
# philosophical ADJ
# science NOUN
# built VERB
# up ADP
# by ADP
# human ADJ
# reason NOUN
# . PUNCT
# Firstly ADV
# , PUNCT
# indeed ADV
# , PUNCT
# because SCONJ
# man NOUN
# is AUX
# directed VERB
# to ADP
# God PROPN
# , PUNCT
# as SCONJ
# to ADP
# an DET
# end NOUN
# that DET
# surpasses VERB
# the DET
# grasp NOUN
# of ADP
# his DET
# reason NOUN
# : PUNCT
# " PUNCT
# The DET
# eye NOUN
# hath NOUN
# not PART
# seen VERB
# , PUNCT
# O INTJ
# God PROPN
# , PUNCT
# besides SCONJ
# Thee PROPN
# , PUNCT
# what PRON
# things NOUN
# Thou PROPN
# hast NOUN
# prepared VERB
# for ADP
# them PRON
# that DET
# wait VERB
# for ADP
# Thee PROPN
# " PUNCT
# ( PUNCT
# Isaiah PROPN
# 64:4 PROPN
# ) PUNCT
# . PUNCT
# But CCONJ
# the DET
# end NOUN
# must VERB
# first ADV
# be AUX
# known VERB
# by ADP
# men NOUN
# who PRON
# are AUX
# to PART
# direct VERB
# their DET
# thoughts NOUN
# and CCONJ
# actions NOUN
# to ADP
# the DET
# end NOUN
# . PUNCT
# Hence ADV
# it PRON
# was AUX
# necessary ADJ
# for ADP
# the DET
# salvation NOUN
# of ADP
# man NOUN
# that SCONJ
# certain ADJ
# truths NOUN
# which DET
# exceed VERB
# human ADJ
# reason NOUN
# should VERB
# be AUX
# made VERB
# known ADJ
# to ADP
# him PRON
# by ADP
# divine ADJ
# revelation NOUN
# . PUNCT
# Even ADV
# as SCONJ
# regards VERB
# those DET
# truths NOUN
# about ADP
# God PROPN
# which DET
# human ADJ
# reason NOUN
# could VERB
# have AUX
# discovered VERB
# , PUNCT
# it PRON
# was AUX
# necessary ADJ
# that DET
# man NOUN
# should VERB
# be AUX
# taught VERB
# by ADP
# a DET
# divine ADJ
# revelation NOUN
# ; PUNCT
# because SCONJ
# the DET
# truth NOUN
# about ADP
# God PROPN
# such ADJ
# as SCONJ
# reason NOUN
# could VERB
# discover VERB
# , PUNCT
# would VERB
# only ADV
# be AUX
# known VERB
# by ADP
# a DET
# few ADJ
# , PUNCT
# and CCONJ
# that SCONJ
# after ADP
# a DET
# long ADJ
# time NOUN
# , PUNCT
# and CCONJ
# with ADP
# the DET
# admixture NOUN
# of ADP
# many ADJ
# errors NOUN
# . PUNCT
# Whereas SCONJ
# man NOUN
# 's PART
# whole ADJ
# salvation NOUN
# , PUNCT
# which DET
# is AUX
# in ADP
# God PROPN
# , PUNCT
# depends VERB
# upon SCONJ
# the DET
# knowledge NOUN
# of ADP
# this DET
# truth NOUN
# . PUNCT
# Therefore ADV
# , PUNCT
# in ADP
# order NOUN
# that SCONJ
# the DET
# salvation NOUN
# of ADP
# men NOUN
# might VERB
# be AUX
# brought VERB
# about ADP
# more ADV
# fitly ADV
# and CCONJ
# more ADV
# surely ADV
# , PUNCT
# it PRON
# was AUX
# necessary ADJ
# that SCONJ
# they PRON
# should VERB
# be AUX
# taught VERB
# divine ADJ
# truths NOUN
# by ADP
# divine ADJ
# revelation NOUN
# . PUNCT
# It PRON
# was AUX
# therefore ADV
# necessary ADJ
# that SCONJ
# besides SCONJ
# philosophical ADJ
# science NOUN
# built VERB
# up ADP
# by ADP
# reason NOUN
# , PUNCT
# there PRON
# should VERB
# be AUX
# a DET
# sacred ADJ
# science NOUN
# learned VERB
# through ADP
# revelation NOUN
# . PUNCT
